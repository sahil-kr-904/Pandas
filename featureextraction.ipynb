# %%
import numpy as np
import pandas as pd

# %%
# Loading the data

# %%
df = pd.read_csv(r'./anime.csv')

# %%
df
# Out:
#     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df.head() # Give top 5 rows of dataframes
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
# make a new column for episode count

# %%
# here,no any feature as episode count is present
# for this I will do feature extraction
# here, I will extract episode count from title

# %%
df.loc[2]["Title"]
# Out:
# 'Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members'

# %%
def episodeCount(title):
    count = ""
    flag = 0
    for i in title:
        if(i==")"):
            break
        if flag:
            count += i
        if(i=="("):
            flag = 1
    return count

# %%
df["Episode_Count"] = df["Title"].apply(episodeCount)

# %%
df
# Out:
#     Rank                                              Title  Score  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df.loc[47]["Episode_Count"]
# Out:
# '12 eps'

# %%
df["Episode_Count"] = df["Episode_Count"].str.replace(" eps","")

# %%
# df.loc[47]["Episode_Count"]
type(df.loc[47]["Episode_Count"])
# Out:
# str

# %%
df["Episode_Count"] = df["Episode_Count"].astype(int)

# %%
type(df.loc[47]["Episode_Count"])
# Out:
# numpy.int64

# %%
# make a new column for time stamp

# %%
df
# Out:
#     Rank                                              Title  Score  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
print(df.loc[3]["Title"])
print(df.loc[4]["Title"])
print(df.loc[5]["Title"])
# Out:
# Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 members
# Shingeki no Kyojin Season 3 Part 2TV (10 eps)Apr 2019 - Jul 20192,146,679 membersManga StoreVolume 1€10.99Preview
# Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 members

# %%
def extract_timestamp(title):
    timestamp = ""
    flag = 0
    track = 0
    for i in title:
        if track==19:
            break
        if flag:
            timestamp += i
            track += 1
        if i==")":
            flag = 1
    return timestamp

# %%
df["Timestamp"] = df["Title"].apply(extract_timestamp)

# %%
df
# Out:
#     Rank                                              Title  Score  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
# which anime has the highest score

# %%
df[df["Score"]==df["Score"].max()]["Title"]
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# Name: Title, dtype: object

# %%
# give me top 5 highest scoring anime

# %%
# Here since it is already arranged in rank wise
# df["Score"].value_counts
# df["Score"].unique
df["Title"].head()
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# 1    Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...
# 2    Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...
# 3    Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...
# 4    Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...
# Name: Title, dtype: object

# %%
# which anime has the highest episode count

# %%
df[df["Episode_Count"]==df["Episode_Count"].max()]
# Out:
#     Rank                                              Title  Score  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94
#
#     Episode_Count            Timestamp
# 15            201  Apr 2006 - Mar 2010

# %%
# animes with top 5 episode count

# %%
df["Episode_Count"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      64
# 1      24
# 2      13
# 3      51
# 4      10
# 5      51
# 6       1
# 7     148
# 8      13
# 9      13
# 10      2
# 11    110
# 12     13
# 13     13
# 14     12
# 15    201
# 16      1
# 17     22
# 18     24
# 19     25
# 20      1
# 21      1
# 22      7
# 23     14
# 24     74
# 25      1
# 26      1
# 27     12
# 28      1
# 29     24
# 30     23
# 31     12
# 32     26
# 33     13
# 34     16
# 35     11
# 36      1
# 37     11
# 38     10
# 39      1
# 40     26
# 41     12
# 42     75
# 43     26
# 44     26
# 45     24
# 46     10
# 47     12
# 48     12
# 49      4
# Name: Episode_Count, dtype: int64>

# %%
df["Episode_Count"].unique
# Out:
# <bound method Series.unique of 0      64
# 1      24
# 2      13
# 3      51
# 4      10
# 5      51
# 6       1
# 7     148
# 8      13
# 9      13
# 10      2
# 11    110
# 12     13
# 13     13
# 14     12
# 15    201
# 16      1
# 17     22
# 18     24
# 19     25
# 20      1
# 21      1
# 22      7
# 23     14
# 24     74
# 25      1
# 26      1
# 27     12
# 28      1
# 29     24
# 30     23
# 31     12
# 32     26
# 33     13
# 34     16
# 35     11
# 36      1
# 37     11
# 38     10
# 39      1
# 40     26
# 41     12
# 42     75
# 43     26
# 44     26
# 45     24
# 46     10
# 47     12
# 48     12
# 49      4
# Name: Episode_Count, dtype: int64>

# %%
df["Episode_Count"].sort_values(ascending=False)
# Out:
# 15    201
# 7     148
# 11    110
# 42     75
# 24     74
# 0      64
# 5      51
# 3      51
# 32     26
# 40     26
# 43     26
# 44     26
# 19     25
# 18     24
# 1      24
# 29     24
# 45     24
# 30     23
# 17     22
# 34     16
# 23     14
# 9      13
# 2      13
# 8      13
# 12     13
# 13     13
# 33     13
# 48     12
# 41     12
# 31     12
# 14     12
# 47     12
# 27     12
# 35     11
# 37     11
# 38     10
# 46     10
# 4      10
# 22      7
# 49      4
# 10      2
# 6       1
# 16      1
# 26      1
# 21      1
# 25      1
# 20      1
# 28      1
# 39      1
# 36      1
# Name: Episode_Count, dtype: int64

# %%
df.loc[df["Episode_Count"].sort_values(ascending=False).index].head()["Title"]
# Out:
# 15    GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...
# 7     Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...
# 11    Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...
# 42    Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...
# 24    MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...
# Name: Title, dtype: object

# %%
df.nlargest(5, "Episode_Count")["Title"]
# Out:
# 15    GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...
# 7     Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...
# 11    Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...
# 42    Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...
# 24    MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...
# Name: Title, dtype: object

# %%
# from chatgpt
from dateutil.relativedelta import relativedelta
from datetime import datetime

def calculate_total_months(period):
    try:
        start_str, end_str = period.split(' - ')
        start_date = datetime.strptime(start_str, '%b %Y')
        end_date = datetime.strptime(end_str, '%b %Y')
        r = relativedelta(end_date, start_date)
        return r.years * 12 + r.months + 1  # +1 to include the starting month
    except:
        return None

df['Months'] = df['Timestamp'].apply(calculate_total_months)

# %%
df.head()
# Out:
#    Rank                                              Title  Score  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
#
#    Episode_Count            Timestamp  Months
# 0             64  Apr 2009 - Jul 2010      16
# 1             24  Apr 2011 - Sep 2011       6
# 2             13  Oct 2022 - Dec 2022       3
# 3             51  Apr 2015 - Mar 2016      12
# 4             10  Apr 2019 - Jul 2019       4

# %%
# which is the longest running anime

# %%
df.nlargest(5,"Months")["Title"]
# Out:
# 11    Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...
# 15    GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...
# 7     Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...
# 32    Kingdom 3rd SeasonTV (26 eps)Apr 2020 - Oct 20...
# 24    MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...
# Name: Title, dtype: object
