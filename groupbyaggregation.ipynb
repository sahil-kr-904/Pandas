# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## GroupBy

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
# Group by Category and calculate sum of Sales
cat = df.groupby("Category") # It creates an object that cannot be seen
for i,v in cat:
    print(i)
    print(v)
print(cat)
# Out:
# A
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 2        A    S2    150        12 2023-01-03
# 4        A    S1    120         8 2023-01-05
# 6        A    S2    200        15 2023-01-07
# B
#   Category Store  Sales  Quantity       Date
# 1        B    S1    200        15 2023-01-02
# 3        B    S2    250        18 2023-01-04
# 5        B    S2    180        20 2023-01-06
# 7        B    S1    300        25 2023-01-08
# ...

# %%
cat["Sales"].sum()
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
# Group by Store and calculate sum of Sales
df.groupby("Store")["Sales"].sum()
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
# GroupBy multiple columns
# GroupBy Category and Store
df.groupby(["Category","Store"])["Sales"].sum()
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %%
df.groupby(["Store","Category"])["Sales"].sum()
# Out:
# Store  Category
# S1     A           220
#        B           500
# S2     A           350
#        B           430
# Name: Sales, dtype: int64

# %% [markdown]
# ## Aggregation

# %% [markdown]
# Combining different values and get the single answer

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
df["Sales"].mean()
# Out:
# np.float64(187.5)

# %%
df["Sales"].median()
# Out:
# np.float64(190.0)

# %%
df["Sales"].mode()
# Out:
# 0    200
# Name: Sales, dtype: int64

# %%
df["Sales"].count()
# Out:
# np.int64(8)

# %%
df["Store"].count() # It gives count of all values
# Out:
# np.int64(8)

# %%
df["Store"].nunique() # It gives count of all unique values
# Out:
# 2

# %%
df["Quantity"].min()
# Out:
# np.int64(8)

# %%
df["Quantity"].max()
# Out:
# np.int64(25)

# %%
df["Quantity"].std() # Standard Deviation
# Out:
# np.float64(5.5533130394644346)

# %%
df["Sales"].agg(["mean","min","max","sum","count","nunique","std"])
# Out:
# mean        187.500000
# min         100.000000
# max         300.000000
# sum        1500.000000
# count         8.000000
# nunique       7.000000
# std          66.062741
# Name: Sales, dtype: float64
