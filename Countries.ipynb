# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"./Countries.csv")

# %%
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
# First, I have to do data preprocessing before starting data analysis
# Data Preprocessing means filling null values with mean or median or mode
# And any extra feature that I can extract then we start analysis

# %%
df.shape
# Out:
# (194, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
df.describe()
# Out:
#          latitude   longitude  agricultural_land   forest_area     land_area  \
# count  194.000000  194.000000       1.930000e+02  1.940000e+02  1.940000e+02
# mean    18.975601   22.027491       2.454551e+05  2.086784e+05  6.675087e+05
# std     23.876225   66.396389       6.356268e+05  7.824926e+05  1.837107e+06
# min    -41.000000 -175.000000       4.000000e+00  0.000000e+00  2.027000e+00
# 25%      4.000000   -5.000000       6.464000e+03  3.331775e+03  2.355250e+04
# 50%     16.583333   21.500000       3.872780e+04  2.528925e+04  1.203750e+05
# 75%     40.000000   50.162500       2.150000e+05  1.236735e+05  5.237000e+05
# max     65.000000  178.000000       5.285080e+06  8.153120e+06  1.637690e+07
#
#          rural_land     urban_land  central_government_debt_pct_gdp  \
# count  1.940000e+02     194.000000                       120.000000
# mean   6.563711e+05    9777.116531                        66.759366
# std    1.811169e+06   42301.458421                        71.806247
# ...

# %%
# Which country has the highest population

# %%
# df[df["population"]==df["population"].max()]["country"].index
df[df["population"]==df["population"].max()]["country"]
# Out:
# 75    India
# Name: country, dtype: object

# %%
# What is the capital of country with highest population

# %%
df[df["population"]==df["population"].max()]["capital_city"]
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
# Which country has the least population

# %%
df[df["population"]==df["population"].min()]["country"]
# Out:
# 179    Tuvalu
# Name: country, dtype: object

# %%
# What is the capital of country with least population

# %%
df[df["population"]==df["population"].min()]["capital_city"]
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %%
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
# Top 5 countries with highest democratic score

# %%
df.sort_values(by="democracy_score",ascending=False)["country"].head()
# Out:
# 127         Norway
# 74         Iceland
# 164         Sweden
# 122    New Zealand
# 46         Denmark
# Name: country, dtype: object

# %%
# How many total regions are there

# %%
df["region"].nunique()
# Out:
# 22

# %%
df["region"].value_counts().count()
# Out:
# np.int64(22)

# %%
# How many countries lie in Eastern Europe region

# %%
df["region"].value_counts()["Eastern Europe"]
# Out:
# np.int64(10)

# %%
df[df["region"]=="Eastern Europe"]["country"].count()
# Out:
# np.int64(10)

# %%
df[df["region"]=="Eastern Europe"]["country"] # Name of all countries in that region
# Out:
# 14             Belarus
# 24            Bulgaria
# 43      Czech Republic
# 73             Hungary
# 111            Moldova
# 136             Poland
# 139            Romania
# 140             Russia
# 151    Slovak Republic
# 181            Ukraine
# Name: country, dtype: object

# %%
# Who is the political leader of 2nd highest populated country

# %%
df.sort_values("population",ascending=False)["political_leader"]
# Out:
# 75             Narendra Modi
# 34                Xi Jinping
# 184                Joe Biden
# 76               Joko Widodo
# 129               Imran Khan
#                ...
# 112                Albert II
# 143       Alessandro Mancini
# 130    Thomas Remengesau Jr.
# 119          Lionel Aingimea
# 179            Kausea Natano
# Name: political_leader, Length: 194, dtype: object

# %%
df[df["population"] == df["population"].nlargest(2).iloc[1]]["political_leader"] # This is the best method
# Out:
# 34    Xi Jinping
# Name: political_leader, dtype: object

# %%
df.sort_values(by="population",ascending=False).iloc[1]["political_leader"]
# Out:
# 'Xi Jinping'

# %%
# How many countries are there whose political leaders are unknown

# %%
df["political_leader"].isna().sum()
# Out:
# np.int64(7)

# %%
df[df["political_leader"].isna()] # All details
# Out:
#                             country                        country_long  \
# 27                       Cabo Verde              Republic of Cabo Verde
# 151                 Slovak Republic                     Slovak Republic
# 159             St. Kitts and Nevis                 St. Kitts and Nevis
# 160                       St. Lucia                           St. Lucia
# 161  St. Vincent and the Grenadines      St. Vincent and the Grenadines
# 172                     Timor-Leste  Democratic Republic of Timor-Leste
# 190              West Bank and Gaza                  West Bank and Gaza
#
#                   currency capital_city              region continent  \
# 27       Cabo Verde escudo        Praia      Western Africa    Africa
# 151                   Euro   Bratislava      Eastern Europe    Europe
# 159  East Caribbean dollar   Basseterre           Caribbean  Americas
# 160  East Caribbean dollar     Castries           Caribbean  Americas
# ...

# %%
# How many country have Republic in their full name

# %%
df["country_long"]
# Out:
# 0                 Islamic State of Afghanistan
# 1                          Republic of Albania
# 2      People's Democratic Republic of Algeria
# 3                      Principality of Andorra
# 4                  People's Republic of Angola
#                         ...
# 189              Socialist Republic of Vietnam
# 190                         West Bank and Gaza
# 191                          Republic of Yemen
# 192                         Republic of Zambia
# 193                       Republic of Zimbabwe
# Name: country_long, Length: 194, dtype: object

# %%
def isRepublic(name):
    if "Republic" in name:
        return True
    return False

# %%
df["country_long"].apply(isRepublic)
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 189     True
# 190    False
# 191     True
# 192     True
# 193     True
# Name: country_long, Length: 194, dtype: bool

# %%
df[df["country_long"].apply(isRepublic)]
# Out:
#        country                             country_long            currency  \
# 1      Albania                      Republic of Albania        Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria      Algerian dinar
# 4       Angola              People's Republic of Angola      Angolan kwanza
# 6    Argentina                       Argentine Republic      Argentine peso
# 7      Armenia                      Republic of Armenia       Armenian dram
# ..         ...                                      ...                 ...
# 187    Vanuatu                      Republic of Vanuatu        Vanuatu vatu
# 189    Vietnam            Socialist Republic of Vietnam     Vietnamese dong
# 191      Yemen                        Republic of Yemen         Yemeni rial
# 192     Zambia                       Republic of Zambia  New Zambian kwacha
# 193   Zimbabwe                     Republic of Zimbabwe         U.S. dollar
#
# ...

# %%
df["country_long"].apply(isRepublic).sum()
# Out:
# np.int64(125)

# %%
# Which country in african region has highest population

# %%
df["region"].value_counts()
# Out:
# region
# Eastern Africa               17
# Western Asia                 17
# Western Africa               16
# Southern Europe              15
# Caribbean                    13
# South America                12
# South-Eastern Asia           11
# Northern Europe              10
# Middle Africa                10
# Eastern Europe               10
# Western Europe                9
# Southern Asia                 9
# Central America               8
# Northern Africa               6
# Micronesia                    5
# Southern Africa               5
# Eastern Asia                  5
# Central Asia                  5
# Melanesia                     4
# Polynesia                     3
# Australia and New Zealand     2
# Northern America              2
# Name: count, dtype: int64

# %%
df[df["continent"] == "Africa"].nlargest(1,"population")["country"]
# Out:
# 125    Nigeria
# Name: country, dtype: object

# %%
# Another method

# %%
african_continent = df[df["continent"] == "Africa"]
largest_poulation_country = african_continent[african_continent["population"]==african_continent["population"].max()]

# %%
largest_poulation_country["country"]
# Out:
# 125    Nigeria
# Name: country, dtype: object
